# %% [markdown]
# # Exercise: Train-Test
#
# In this exercise, we'll use the `../data/songs_clean.csv` dataset.
#
# ## Instructions
#
# Read the [sklearn.model_selection.train_test_split](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) documentation.
#
# Execute the steps.
#
# Use a Pandas DataFrame named `X` to read the `songs_clean.csv`.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# read CSV

# %% [markdown]
# Find the target variable. It's a numeric type. Play around with it. Be flexible.
#
# The target variable, `y`, is a Series. We can use [DataFrame.pop](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.pop.html) or `y = X["numeric_col"]` then drop the column.

# %%
# target variable

# %% [markdown]
# Use the `train_test_split` function.
#
# **Example**
#
# ```py
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)
# ```
#
# **Input**
# - `X` is a DataFrame
# - `y` is a Series
# - `test_size=0.30` or 30% of test records
# - `random_state` is an integer. We can choose, though we want a fixed integer.
#
# **Output**
# - `X_train` is a DataFrame
# - `X_test` is a DataFrame
# - `y_train` is a Series
# - `y_test` is a Series

# %%
# train_test_split

# %% [markdown]
# Use the [.describe()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html) method to generate descriptive statistics for the training and test sets.

# %%
# .describe is a DataFrame and Series method

# %% [markdown]
# # Exercise: K-Means Clustering
#
# We'll use the [iris dataset](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html).
#
# ## Instructions
#
# Read through the documentation below for guidance, then execute the following steps.
#
# - [sklearn.datasets.load_iris](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html)
#
# - [StandardScaler](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html)
#
# - [Clustering: K-means](https://scikit-learn.org/stable/modules/clustering.html#k-means)
#
# - [KMeans model](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html)
#
# 1\. Use the clean iris dataset. There are no `na`s. Load it as a Pandas DataFrame (`as_frame=True`).

# %%
# load_iris

# %% [markdown]
# 2\. Use the [StandardScalar](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html).

# %%
# StandardScaler

# %% [markdown]
# 3\. Create a model from K=2 through K=5 clusters, inclusive. Create a scatterplot for each model, using color to distinguish between clusters.

# %%
# KMeans

# %% [markdown]
# 4\. Create additional models for K=1 through K=20, inclusive. Generate a scree plot for all 20 models we've created. (Hint: use the `.inertia_` attribute of your K-means instance as your vertical axis values.) Judging from the scree plot, what appears to be a reasonable choice of K for this dataset?

# %%
# inertias

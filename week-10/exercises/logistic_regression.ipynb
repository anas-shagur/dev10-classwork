# %% [markdown]
# # Exercise: Logistic Regression
#
# ## Introduction
#
# In this exercise, we'll use the [LogisticRegressionCV](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegressionCV.html) model.
#
# ### Set Up
#
# 1\. Import the `diabetes.csv` dataset into a Pandas DataFrame.

# %%
import pandas as pd

# ../data/diabetes.csv

# %% [markdown]
# 2\. Clean the data and remove missing values. (There are none.)
#
# 3\. Drop any column that is not categorical or numeric. (There are none.)
#
# 4\. Separate the independent variables from the dependent variables. The dependent variable is `Outcome`.

# %%
# Outcome is the target variable

# %% [markdown]
# 5\. Generate dummy variables for the categorical features. (There are none.)
#
# 6\. Use `train_test_split`. The testing set is 25% of our dataset. We can choose `random_state`, though it needs to be a constant value.

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# 7\. Fit the model using the `LogisticRegressionCV` class. Which hyperparameter performs best in cross-validation?

# %%
from sklearn.linear_model import LogisticRegressionCV

# print(f"Best C: {classifier.C_}")

# %% [markdown]
# 8\. Use the model to generate predictions on the test set.

# %%
# predict

# %% [markdown]
# 9\. Print a confusion matrix and a classification report from `y_test` and `y_pred`.

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# 10\. Print the Matthews correlation coefficient.

# %%
from sklearn.metrics import matthews_corrcoef

# %% [markdown]
# ## Stretch Goals
#
# - Visualize a confusion matrix with either a [ConfusionMatrixDisplay](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.ConfusionMatrixDisplay.html) or a [seaborn.heatmap](https://seaborn.pydata.org/generated/seaborn.heatmap.html).
#
# - Visualize a ROC Curve with either a [RocCurveDisplay](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.RocCurveDisplay.html) or [matplotlib.pyplot.plot](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html) (this is included with [auc](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.auc.html) and [roc_curve](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html)).
#
# - We need to have an intuition about features. Do we remove features? Create derived features? There are also [sklearn.preprocessing](https://scikit-learn.org/stable/api/sklearn.preprocessing.html) APIs that are effective.
